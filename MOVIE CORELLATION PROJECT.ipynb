# %%
# import liberies 
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjust the configuration of the plot we will create

df =pd.read_csv(r'C:\Users\hp\Downloads\movies.csv.zip')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print ('()-()%'.format(col,pct_missing))
# Out:
# ()-()%
# ()-()%
# ()-()%
# ()-()%
# ()-()%
# ()-()%
# ()-()%
# ()-()%
# ()-()%
# ()-()%
# ()-()%
# ()-()%
# ()-()%
# ()-()%
# ()-()%

# %%
pd.options.mode.chained_assignment = None

# %%
df.dtypes.head()
# Out:
# name        object
# rating      object
# genre       object
# year         int64
# released    object
# dtype: object

# %%
#changung NaN to zero(0)

df['budget'].isna().sum()
# Out:
# 0

# %%
df['budget'].fillna(0,inplace=True)

# %%
df['budget']=df['budget'].astype('int64')

# %%
df['votes'].isna().sum()
# Out:
# 0

# %%
df['votes'].fillna(0,inplace=True)

# %%
df['votes']=df['votes'].astype('int64')

# %%
df['gross'].isna().sum()
# Out:
# 0

# %%
df['gross'].fillna(0,inplace=True)

# %%
df['gross']=df['gross'].astype('int64')

# %%
df['runtime'].isna().sum()
# Out:
# 0

# %%
df['runtime'].fillna(0,inplace=True)

# %%
df['runtime']=df['runtime'].astype('int64')

# %%
#create a correct year column
df['correctyear']=df['released'].astype(str)[:7668]
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#order by gross Revenue

df.sort_values(by=['gross'],inplace=False,ascending=False).head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
#looking at the whole data set

pd.set_option('display.max_rows',None)

# %%
# check for duplicates,then drop duplicate
df['company'].sort_values(ascending=False)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# correlation between buget and gross
# correlation between company and gross
#correlation between votes and gross

plt.scatter(x=df['budget'],y=df['gross'])

plt.xlabel('Gross Earnigs')

plt.ylabel('Movie Budget')

plt.title('Correlation between Budget and Gross Earnings')

plt.show()

# %%
# regression line

sns.regplot(x='budget',y='gross',data=df, scatter_kws={"color":"red"}, line_kws={"color":"black"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
df.corr(method='pearson')  #pearson,kendall,spearman
# Out:
#              year     score     votes    budget     gross   runtime      vote
# year     1.000000  0.097995  0.222427  0.309212  0.261900  0.116358  0.222427
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.398387  0.409182
# votes    0.222427  0.409182  1.000000  0.486931  0.632870  0.306984  1.000000
# budget   0.309212  0.055665  0.486931  1.000000  0.750157  0.268372  0.486931
# gross    0.261900  0.186392  0.632870  0.750157  1.000000  0.244339  0.632870
# runtime  0.116358  0.398387  0.306984  0.268372  0.244339  1.000000  0.306984
# vote     0.222427  0.409182  1.000000  0.486931  0.632870  0.306984  1.000000

# %%
correlation_matrix=df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.title('correlation Matrix')

plt.show()

# %%
#correlation between votes and gross

plt.scatter(x=df['budget'],y=df['gross'])

plt.xlabel('Gross Earnigs')

plt.ylabel('votes')

plt.title('Correlation between Budget and Gross Earnings')

plt.show()

# %%
sns.regplot(x='votes',y='gross',data=df, scatter_kws={"color":"green"}, line_kws={"color":"red"})
# Out:
# <AxesSubplot:xlabel='votes', ylabel='gross'>

# %%
#look company and gross correlation

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]=df_numerized[col_name].astype('category')
        df_numerized[col_name]=df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score    votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000      1111    2567
# 3   286       4      4  1980      1492    7.7   221000      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000      1054     521
#
#    star  country    budget      gross  company  runtime  correctyear
# 0  1047       54  19000000   46998772     2319      146         1705
# 1   327       55   4500000   58853106      731      104         1492
# 2  1745       55  18000000  538375067     1540      124         1771
# 3  2246       55   3500000   83453539     1812       88         1492
# 4   410       55   6000000   39846344     1777       98         1543

# %%
correlation_matrix=df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.title('correlation Matrix')

plt.show()

# %%
df_numerized.corr().head()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
#
#              votes  director    writer      star   country    budget  \
# name      0.013038  0.009079  0.009081  0.006472 -0.010737  0.020548
# rating    0.033743  0.019483 -0.005921  0.013405  0.081244 -0.081939
# genre    -0.145296 -0.015258  0.006567 -0.005477 -0.037615 -0.334021
# year      0.222427 -0.020795 -0.008656 -0.027242 -0.070938  0.309212
# released  0.015878 -0.001478 -0.002404  0.015777 -0.020427  0.009145
#
#              gross   company   runtime  correctyear
# name      0.006989  0.009211  0.008483    -0.010480
# ...

# %%
# for better identification 
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs.head()
# Out:
# name  name        1.000000
#       rating     -0.008069
#       genre       0.016355
#       year        0.011453
#       released   -0.011311
# dtype: float64

# %%
sorted_pairs=corr_pairs.sort_values()
sorted_pairs.head()
# Out:
# genre   budget   -0.334021
# budget  genre    -0.334021
# genre   gross    -0.234297
# gross   genre    -0.234297
# genre   votes    -0.145296
# dtype: float64

# %%
high_corr=sorted_pairs[(sorted_pairs)>0.5]
high_corr.head()
# Out:
# votes        gross       0.632870
# gross        votes       0.632870
# budget       gross       0.750157
# gross        budget      0.750157
# correctyear  released    0.998458
# dtype: float64

# %%
#Note budget and vote have a high correlation,that is the higher the budget of a movie the high the gross revernue obtained. 
#company has a low correltion,contary to suggested
